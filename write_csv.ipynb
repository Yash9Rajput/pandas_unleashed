# %% [markdown]
# ##write csv file

# %%
import pandas as pd

dic = {"a":[1,2,3,4,5,6] , "b": [7,8,9,10,11,12] , "c": [13, 14, 15, 16, 17, 18]}

d = pd.DataFrame(dic , index = ['q','w','e','r','t','y'])
print(d)

#d.to_csv("Test_1.csv")
#d.to_csv("Test_2.csv" , index = False)
d.to_csv("Test_3.csv" , index= False , header = [1,2,3])
# Out:
#    a   b   c
# q  1   7  13
# w  2   8  14
# e  3   9  15
# r  4  10  16
# t  5  11  17
# y  6  12  18
