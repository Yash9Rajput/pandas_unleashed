# %% [markdown]
# ##insert

# %%
import pandas as pd

var = pd.DataFrame({"A": [1,2,3,4,5] , "B":[6,7,8,9,10]})
var
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
var.insert(1,"python_2" , var["A"])
var
# Out:
#    A  python_2  python_1  python   B
# 0  1         1         1       1   6
# 1  2         2         2       2   7
# 2  3         3         3       3   8
# 3  4         4         4       4   9
# 4  5         5         5       5  10

# %%
var.insert(1, "python_5" , [11,12,13,14,15])
var
# Out:
#    A  python_5  python_4  python_3  python_2  python_1  python   B
# 0  1        11        11        11         1         1       1   6
# 1  2        12        12        12         2         2       2   7
# 2  3        13        13        13         3         3       3   8
# 3  4        14        14       141         4         4       4   9
# 4  5        15        15        15         5         5       5  10

# %%
var["py"] = var["A"][:3]
var
# Out:
#    A  python_5  python_4  python_3  python_2  python_1  python   B   py
# 0  1        11        11        11         1         1       1   6  1.0
# 1  2        12        12        12         2         2       2   7  2.0
# 2  3        13        13        13         3         3       3   8  3.0
# 3  4        14        14       141         4         4       4   9  NaN
# 4  5        15        15        15         5         5       5  10  NaN

# %% [markdown]
# ##Delete

# %%
var_5 = var.pop("python")
var_5
var

print(var_5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\asus\Documents\pandas_unleashed\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'python'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 var_5 = var.pop("python")
# ...

# %%
print(var.columns)
print(var_5)
print(type(var_5))
print(var)
# Out:
# Index(['A', 'python_2', 'python_1', 'B', 'py'], dtype='object')
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: python, dtype: int64
# <class 'pandas.core.series.Series'>
#    A  python_2  python_1   B   py
# 0  1         1         1   6  1.0
# 1  2         2         2   7  2.0
# 2  3         3         3   8  3.0
# 3  4         4         4   9  NaN
# 4  5         5         5  10  NaN
